# %%
import os
import zipfile
from PIL import Image
import numpy as np
from alive_progress import alive_bar
import time

# Define paths
images_path = './data/extracted_data/ikea-master/images/'
save_path = './data/extracted_data/ikea_processed_data/images/'

# Creating save path if nopt exist:
os.makedirs(save_path,exist_ok=True)

# Define traget size 
target_size = (512,512)

# %%
def preprocess_image(image_path):
    with Image.open(image_path) as img:
        img = img.resize(target_size)
        return img

def save_preprocessed_image(img, image_name, save_path):
    os.makedirs(save_path,exist_ok=True)
    img.save(os.path.join(save_path, image_name+'.jpg'))

categories = os.listdir(images_path)
for category in categories:
    with alive_bar(len(os.listdir(os.path.join(images_path,category)))) as bar:
        for images in os.listdir(os.path.join(images_path,category)):
            # print(images)
            image_path = os.path.join(images_path,category,images)
            img = preprocess_image(image_path)
            image_file = images.split('.jp')[0]
            save_preprocessed_image(img, image_file, save_path)
            time.sleep(.001)
            bar()
# Out:
# |████████████████████████████████████████| 34/34 [100%] in 0.4s (86.70/s)
# |████████████████████████████████████████| 54/54 [100%] in 0.6s (89.40/s)
# |████████████████████████████████████████| 40/40 [100%] in 0.4s (97.99/s)
# |████████████████████████████████████████| 106/106 [100%] in 1.0s (101.05/s)
# |████████████████████████████████████████| 1859/1859 [100%] in 19.2s (96.77/s)
# |████████████████████████████████████████| 117/117 [100%] in 1.2s (95.28/s)
# |████████████████████████████████████████| 215/215 [100%] in 4.4s (48.61/s)
# |████████▎⚠︎                              | (!) 22/107 [21%] in 0.5s (43.91/s)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     628     try:
# --> 629         rawmode = RAWMODE[im.mode]
#     630     except KeyError as e:
#
# KeyError: 'RGBA'
#
# ...

# %%
a = np.array(img)
a.shape
# Out:
# (512, 512, 3)

# %%
img = img.convert("RGB")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7FF720CE0EE0>

# %%
# Define paths
import pickle
text_path = './data/extracted_data/ikea-master/text_data/'
save_path = './data/extracted_data/ikea_processed_data/pickle_processed/'

pickle_files = os.listdir(text_path)

# %%
for pickle_file in pickle_files[:1]:
    print('extracting {} pickle file'.format(pickle_file))
    with open(os.path.join(text_path,pickle_file), 'rb') as file:
        deserialized_data = pickle.load(file)
# Out:
# extracting products_dict.p pickle file

# %%
# for image_filename, catgeory in deserialized_data.items():
deserialized_data.items()
# Out:
# dict_items([('/static/images/500.210.76.jpg', {'desc': 'Your child can use it for different purposes. The easel has a whiteboard on one side and a blackboard on the other.', 'name': 'MLA'}), ('/static/images/802.538.09.jpg', {'desc': 'Turned upside down the bed quickly converts from a low to a high bed.', 'name': 'KURA'}), ('/static/images/802.962.48.jpg', {'desc': 'Made from 100% cotton, a natural material thats soft against your childs skin and gets softer with every wash.', 'name': 'STICKAT'}), ('/static/images/502.962.97.jpg', {'desc': 'Clever storage solution that you can hang on our childrens beds.', 'name': 'STICKAT'}), ('/static/images/203.086.97.jpg', {'desc': 'A playful and sturdy storage series for storing and organising toys, sitting, playing and relaxing.', 'name': 'TROFAST'}), ('/static/images/302.980.23.jpg', {'desc': 'Fits in TROFAST frames.', 'name': 'TROFAST'}), ('/static/images/501.158.62.jpg', {'desc': 'Fits in TROFAST frames.', 'name': 'TROFAST'}), ('/static/imag
# ...

# %%
pickle_file
# Out:
# 'img_to_desc.p'

# %%
len(category)
# Out:
# 2

# %%
annotations = []
for image_filename, category in deserialized_data.items():
    # annotations.append({
    #     "file_name" :  image_filename,
    #     "annotations" : catgeory
    # })
    # print(image_filename, category)

# %%
path = './data/extracted_data/ikea_processed_data/images/'
files = os.listdir('')
print(len(files))
# Out:
# 2509

# %%
for file in files:
    if file.isin(files):
        os.remove(os.path.join())
